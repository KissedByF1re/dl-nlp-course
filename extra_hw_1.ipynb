# %% [markdown]
# **Дополнительное домашнее задание 1 - 10 баллов**
#
# 1. Загрузите набор данных lenta-ru-news с помощью библиотеки Corus для задачи классификации текстов по топикам
# 2. Опишите, насколько, по вашему мнению, данные требуют предобработки для задачи тематического моделирования. При необходимости, проведите релевантную предобработку текстов. **1 балл**
# 3. Используйте библиотеку BERTopic для тематического моделирования:
#     - Подберите оптимальные, на ваш взгляд, элементы пайплайна: энкодер, снижение размерности, алгоритм кластеризации, способ токенизации, постобработку/тюнинг.
# При выборе инструмента на каждом шаге опишите, почему был выбран именно он среди многочисленных альтернатив. **2 балла**
#     - Настройте ваш пайплайн, подобрав оптимальные гиперпараметры для отдельных шагов. При выборе значений конкретных гиперпараметров укажите, почему остановились на тех или иных значениях. **1 балл**
# 4. Визуализируйте полученные результаты: **2 балла**
#     - Топ-токены для каждого топика.
#     - Документы с их топиками в 2D пространстве
#     - Распределение тем по токенам для выборочных текстов из датасета
# 5. Оцените формальное качество лучшего результата с помощью метрик для тематического моделирования:  **2 балла**
#     - Topic Diversity
#     - UMass Coherence
# Hint: реализацию можно написать самостоятельно или поискать в таких библиотеках, как [Gensim](https://github.com/piskvorky/gensim) и [OSTIS](https://github.com/MIND-Lab/OCTIS)
# 6. Проанализируйте полученные результаты в совокупности и резюмируйте, что удалось, какие проблемы вы заметили, как их можно решить в дальнейшем. **1 балл**
#
# **Задание выполнялось в Google Colab**

# %%
# !pip install corus

# %%
# !pip install natasha

# %%
# !pip install bertopic

# %%
import nltk
import pandas as pd
import numpy as np
import math
import re
import spacy
import nltk
import random
from corus import load_lenta

from natasha import Doc, Segmenter, MorphVocab, NewsEmbedding, NewsMorphTagger
from nltk.corpus import stopwords
from tqdm.auto import tqdm
import urllib.request
from hdbscan import HDBSCAN

from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import DBSCAN
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction

from collections import defaultdict

# %%
# Обеспечим воспроизводимость ноутбука
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
random.seed(RANDOM_STATE)

# %% [markdown]
# **1. Загрузка и предобработка данных**

# %% [markdown]
# Чтобы улучшить качество тематического моделирования необходимо выполнить стандартную предобработку текста:
# - удалить знаки препинания (не несут смысловой нагрузки)
# - токенизировать текст (разделим текст на слова)
# - удалить стоп-слова (избежим влияния частых и неинформативных слов)
# - лемматизация (чтобы темы не зависели от формы слова)

# %%
# !wget https://github.com/yutkin/Lenta.Ru-News-Dataset/releases/download/v1.0/lenta-ru-news.csv.gz

# %%
path = 'lenta-ru-news.csv.gz'
records = load_lenta(path)

print(next(records))
# Out:
# LentaRecord(url='https://lenta.ru/news/2018/12/14/cancer/', title='Названы регионы России с\xa0самой высокой смертностью от\xa0рака', text='Вице-премьер по социальным вопросам Татьяна Голикова рассказала, в каких регионах России зафиксирована наиболее высокая смертность от рака, сообщает РИА Новости. По словам Голиковой, чаще всего онкологические заболевания становились причиной смерти в Псковской, Тверской, Тульской и Орловской областях, а также в Севастополе. Вице-премьер напомнила, что главные факторы смертности в России — рак и болезни системы кровообращения. В начале года стало известно, что смертность от онкологических заболеваний среди россиян снизилась впервые за три года. По данным Росстата, в 2017 году от рака умерли 289 тысяч человек. Это на 3,5 процента меньше, чем годом ранее.', topic='Россия', tags='Общество', date=None)

# %%
df = pd.DataFrame(((r.text) for r in records), columns=['text'])
df.head()
# Out:
#                                                 text
# 0  Австрийские правоохранительные органы не предс...
# 1  Сотрудники социальной сети Instagram проанализ...
# 2  С начала расследования российского вмешательст...
# 3  Хакерская группировка Anonymous опубликовала н...
# 4  Архиепископ канонической Украинской православн...

# %%
# Насэмплируем случайным образом 10_000 текстов, чтобы
df_sample = df.sample(n=10000, random_state=42)

# %%
nltk.download('stopwords')

# %%
# Список русских стоп-слов
russian_stopwords = set(stopwords.words("russian"))

def remove_stopwords(text):
    # Убираем пунктуацию и приводим к нижнему регистру
    words = re.findall(r'\w+', text.lower())
    filtered = [word for word in words if word not in russian_stopwords]
    return ' '.join(filtered)

tqdm.pandas(desc="Delete stop-words")

# Применим к нашим данным
df_sample['cleaned'] = df_sample['text'].progress_apply(remove_stopwords)
# Out:
# Delete stop-words:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
df_sample.head()
# Out:
#                                                      text  \
# 153198  Группа ученых из Принстонского университета и ...
# 169154  В Северо-Кавказском окружном военном суде выне...
# 83745   Президент России Владимир Путин поздравил евре...
# 10029   Американская супермодель и участница реалити-ш...
# 6445    Житель британского города Уэстклифф-он-Си (гра...
#
#                                                   cleaned
# 153198  группа ученых принстонского университета униве...
# 169154  северо кавказском окружном военном суде вынесл...
# 83745   президент россии владимир путин поздравил евре...
# 10029   американская супермодель участница реалити шоу...
# 6445    житель британского города уэстклифф си графств...

# %%
# Инициализируем модели Natasha
segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)

# %%
# Функция лемматизации
def lemmatize_text(text):
    doc = Doc(text)
    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)

    lemmas = []
    for token in doc.tokens:
        token.lemmatize(morph_vocab)
        lemmas.append(token.lemma)

    return ' '.join(lemmas)

tqdm.pandas(desc="Lemmatization")

# Применим к нашим данным
df_sample['lemmatized'] = df_sample['cleaned'].progress_apply(lemmatize_text)
# Out:
# Lemmatization:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
df_sample.head()
# Out:
#                                                      text  \
# 153198  Группа ученых из Принстонского университета и ...
# 169154  В Северо-Кавказском окружном военном суде выне...
# 83745   Президент России Владимир Путин поздравил евре...
# 10029   Американская супермодель и участница реалити-ш...
# 6445    Житель британского города Уэстклифф-он-Си (гра...
#
#                                                   cleaned  \
# 153198  группа ученых принстонского университета униве...
# 169154  северо кавказском окружном военном суде вынесл...
# 83745   президент россии владимир путин поздравил евре...
# 10029   американская супермодель участница реалити шоу...
# 6445    житель британского города уэстклифф си графств...
#
#                                                lemmatized
# 153198  группа ученый принстонский университет универс...
# 169154  северо кавказский окружный военный суд вынести...
# 83745   президент россия владимир путин поздравить евр...
# 10029   американский супермодель участница реалить шоу...
# 6445    житель британский город уэстклифф си графство ...

# %% [markdown]
# **2. BERTopic**

# %% [markdown]
# **2.1 Модель эмбеддингов:**
#
# Модель основана на cointegrated/LaBSE-en-ru - имеет аналогичные размеры контекста (512), эмбеддингов (768) и достаточно быстрая. Думаю она неплохо подойдет под условия нашей задачи.

# %%
embedding_model = SentenceTransformer("sergeyzh/LaBSE-ru-turbo")

# %% [markdown]
# **2.2 DIM модель:**
#
# Обычно для снижения размерности эмбеддингов перед кластеризацией в **BERTopic** используется **UMAP** . Однако **TruncatedSVD** — более стабильный и лучше работает с разреженными матрицами (например, TF-IDF), а также быстрее и воспроизводимее, особенно для большого объёма текстов, поэтому будем использовать его.

# %%
dim_model = TruncatedSVD(
    n_components=300,  # Подбираем по explained variance
    n_iter=10,  # Лучше сходимость
    random_state=42,  # воспроизводимость
)

# %% [markdown]
# **2.3 Cluster модель:**
#
# **HDBSCAN** — продвинутый алгоритм кластеризации, способный определять кластеры различной плотности и выделять шум (неприменимые тексты). Это важно при работе с новостными текстами, где могут встречаться выбросы или разнородные темы.

# %%
cluster_model = HDBSCAN(
    min_cluster_size=5,
    min_samples=1,
    metric='euclidean',
    cluster_selection_method='leaf',
    prediction_data=True,
)

# %% [markdown]
# **2.4 Векторизация:**
#
# Простой и эффективный способ извлечения частотных признаков из текста. TF-IDF придаёт больший вес словам, специфичным для темы, что важно для выделения ключевых слов темы. Это основной способ перевода текста в вектор перед применением c-TF-IDF.

# %%
vectorizer_model = TfidfVectorizer()

# %% [markdown]
# **2.5 с-TF-IDF:**
#
# Class-based TF-IDF (c-TF-IDF) — особая адаптация TF-IDF, в которой тексты одного кластера обрабатываются как единый документ. Это усиливает тематические различия между кластерами.

# %%
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# %% [markdown]
# **2.6 Representation model:**
#
# Используется для переопределения ключевых слов, описывающих тему, на основе их семантической значимости (а не только частоты). KeyBERTInspired пересчитывает наиболее репрезентативные ключевые слова с учётом контекста. Это особенно полезно для повышения качества интерпретации тем, особенно на русском, где ключевые слова могут быть многозначны.

# %%
representation_model = KeyBERTInspired()

# %%
# Собираем нашу модель из загруженных компонентов
topic_model = BERTopic(
  embedding_model=embedding_model,          # Step 1 - Extract embeddings
  umap_model=dim_model,                     # Step 2 - Reduce dimensionality
  hdbscan_model=cluster_model,              # Step 3 - Cluster reduced embeddings
  vectorizer_model=vectorizer_model,        # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model,                # Step 5 - Extract topic words
  representation_model=representation_model # Step 6 - (Optional) Fine-tune topic represenations
)

# %%
#Обучаем модель

# %%time

topics, probs = topic_model.fit_transform(df_sample['lemmatized'])
# Out:
# CPU times: user 4min 41s, sys: 1.22 s, total: 4min 42s
# Wall time: 4min 35s

# %% [markdown]
# **3. Визуализация**

# %% [markdown]
# **Визуализируем топ-10 тем**

# %%
topic_model.get_topic_info()[1:11]
# Out:
#     Topic  Count                                               Name  \
# 1       0     52                  0_студийный_scars_пластинка_лейбл
# 2       1     37             1_playstation_геймер_eurogamer_fallout
# 3       2     33               2_украинец_боксерский_весовой_кличко
# 4       3     33  3_ходорковский_лжепредпринимательство_ходатайс...
# 5       4     28  4_звездообразование_астрономический_астрофизик...
# 6       5     24           5_сербский_югославский_серб_черногорский
# 7       6     24               6_котировка_понизиться_фьючерс_биржа
# 8       7     23  7_космический_космодром_аккумуляторный_орбитал...
# 9       8     22              8_донецкий_ополченец_украиной_силовик
# 10      9     22      9_генетический_генетик_геном_neanderthalensis
#
#                                        Representation  \
# 1   [студийный, scars, пластинка, лейбл, сольный, ...
# 2   [playstation, геймер, eurogamer, fallout, kill...
# 3   [украинец, боксерский, весовой, кличко, boxing...
# 4   [ходорковский, лжепредпринимательство, ходатай...
# 5   [звездообразование, астрономический, астрофизи...
# 6   [сербский, югославский, серб, черногорский, ба...
# 7   [котировка, понизиться, фьючерс, биржа, фондов...
# 8   [космический, космодром, аккумуляторный, орбит...
# 9   [донецкий, ополченец, украиной, силовик, минск...
# 10  [генетический, генетик, геном, neanderthalensi...
#
#                                   Representative_Docs
# 1   [группа оззи осборн black sabbath появиться за...
# 2   [студия platinumgames заинтересовать создание ...
# 3   [бывший чемпион мир бокс тяжелый вес американе...
# 4   [отношение михаил ходорковский платон лебедев ...
# 5   [астроном удаться обнаружить островок спокойст...
# 6   [социалистический партия сербия войти коалиция...
# 7   [российский фондовый индекс 9 август прервать ...
# 8   [новый израильский аэробаллистический ракета r...
# 9   [украинский силовик усилить свой позиция горло...
# 10  [современный человек мигрант африка победить е...

# %% [markdown]
# **Посмотрим на самые популяные слова в топ-30 тем**

# %%
topic_model.visualize_barchart(top_n_topics=30, n_words=10, title='Топ слов по темам')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0eb74ef1-2821-4023-9932-ce91e646dd7c" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0eb74ef1-2821-4023-9932-ce91e646dd7c")) {                    Plotly.newPlot(                        "0eb74ef1-2821-4023-9932-ce91e646dd7c",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.6182006001472473,0.6201558709144592,0.6256688237190247,0.6292569637298584,0.6294553875923157,0.6334865093231201,0.6358143091201782,0.6381850838661194,0.6413043141365051,0.6608066558837891],"y":["floyd  ","lips  ","pistols  ","хит  ","strokes  ","сольный  ","лейбл  ","пластинка  ","scars  ","студийный  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.6081961393356323,0.6104677319526672,0.6114824414253235,0.6152006387710571,0.6175668239593506,0.6185617446899414,0.6201653480529785,0.6207484602928162,0.6299876570701599,0.6723722219467163],"y":["gears  ","fable  ","кодзима  ","ролевый  ","games  ","killzone  ","fallout  ","eurogamer  ","геймер  ","playstation  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.6086962223052979,0.6096082925796509,0.6156232357025146,0.617296576499939,0.6202945709228516,0.629445493221283,0.6370738744735718,0.6403323411941528,0.6420755982398987,0.6482171416282654],"y":["ринге  ","полутяжелый  ","претендент  ","тяжеловес  ","боксер  ","boxingscene  ","кличко  ","весовой  ","боксерский  ","украинец  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.5678178668022156,0.5691352486610413,0.5761533379554749,0.5785431861877441,0.58412104845047,0.5983282327651978,0.6119365692138672,0.6195700168609619,0.6331720352172852,0.6704983711242676],"y":["харчилав  ","аффилировать  ","хамовнический  ","подследственный  ","предвзятость  ","уклонение  ","юриспруденция  ","ходатайство  ","лжепредпринимательство  ","ходорковский  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.610418438911438,0.6112673878669739,0.6172264814376831,0.6190223097801208,0.6432458758354187,0.6438466906547546,0.6554739475250244,0.656092643737793,0.6620335578918457,0.671883761882782],"y":["межзвездный  ","экзопланета  ","astrophysical  ","излучение  ","частица  ","галактика  ","астроном  ","астрофизик  ","астрономический  ","звездообразование  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.6435895562171936,0.644869863986969,0.6454930901527405,0.6470898389816284,0.6482487916946411,0.6539803147315979,0.6556727290153503,0.666621744632721,0.6805875301361084,0.705726146697998],"y":["караджич  ","сербия  ","николич  ","сребренице  ","боснийский  ","балканский  ","черногорский  ","серб  ","югославский  ","сербский  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.5626626014709473,0.5645583868026733,0.5705136656761169,0.5737857818603516,0.5745350122451782,0.5755754709243774,0.5761454105377197,0.5838149785995483,0.5857493877410889,0.5884698033332825],"y":["подешеветь  ","дешеветь  ","западноевропейский  ","валютный  ","снизиться  ","фондовый  ","биржа  ","фьючерс  ","понизиться  ","котировка  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.6132888197898865,0.6145673394203186,0.614799976348877,0.6154032349586487,0.6182905435562134,0.6196422576904297,0.6231390237808228,0.6233813166618347,0.6283962726593018,0.6733452081680298],"y":["ads  ","ракетный  ","испытание  ","пилотировать  ","спутниковый  ","аэробаллистический  ","орбитальный  ","аккумуляторный  ","космодром  ","космический  "],"type":"bar","xaxis":"x8","yaxi ...

# %% [markdown]
# **Посмотрим на тему `[1]` в документе `[1]`**

# %%
topic_distr, topic_token_distr = topic_model.approximate_distribution(df_sample['lemmatized'], calculate_tokens=True, batch_size=100)

# %%
df_example = topic_model.visualize_approximate_distribution(df_sample['lemmatized'].iloc[1], topic_token_distr[1])
df_example
# Out:
# <style type="text/css">
# #T_30a38_row0_col0, #T_30a38_row0_col1, #T_30a38_row0_col2, #T_30a38_row0_col3, #T_30a38_row0_col4, #T_30a38_row0_col5, #T_30a38_row0_col6, #T_30a38_row0_col7, #T_30a38_row0_col8, #T_30a38_row0_col9, #T_30a38_row0_col10, #T_30a38_row0_col11, #T_30a38_row0_col12, #T_30a38_row0_col13, #T_30a38_row0_col14, #T_30a38_row0_col15, #T_30a38_row0_col16, #T_30a38_row0_col17, #T_30a38_row0_col18, #T_30a38_row0_col19, #T_30a38_row0_col20, #T_30a38_row0_col21, #T_30a38_row0_col22, #T_30a38_row0_col23, #T_30a38_row0_col24, #T_30a38_row0_col25, #T_30a38_row0_col31, #T_30a38_row0_col32, #T_30a38_row0_col33, #T_30a38_row0_col34, #T_30a38_row0_col35, #T_30a38_row0_col36, #T_30a38_row0_col37, #T_30a38_row0_col38, #T_30a38_row0_col39, #T_30a38_row0_col40, #T_30a38_row0_col41, #T_30a38_row0_col42, #T_30a38_row0_col43, #T_30a38_row0_col44, #T_30a38_row0_col45, #T_30a38_row0_col46, #T_30a38_row0_col47, #T_30a38_row0_col48, #T_30a38_row0_col49, #T_30a38_row0_col50, #T_30a38_row0_col51, #T_30a38_row0_col52, #T_30a38_row0_col53, #T_30a38_row0_col54, #T_30a38_row0_col55, #T_30a38_row0_col56, #T_30a38_row0_col57, #T_30a38_row0_col58, #T_30a38_row0_col59, #T_30a38_row0_col60, #T_30a38_row0_col61, #T_30a38_row0_col62, #T_30a38_row0_col63, #T_30a38_row0_col64, #T_30a38_row0_col65, #T_30a38_row0_col66, #T_30a38_row0_col67, #T_30a38_row0_col68, #T_30a38_row0_col69, #T_30a38_row0_col70, #T_30a38_row0_col71, #T_30a38_row0_col72, #T_30a38_row0_col73, #T_30a38_row0_col74, #T_30a38_row0_col75, #T_30a38_row0_col76, #T_30a38_row0_col77, #T_30a38_row0_col78, #T_30a38_row0_col79, #T_30a38_row0_col80, #T_30a38_row0_col81, #T_30a38_row0_col82, #T_30a38_row0_col83, #T_30a38_row0_col84, #T_30a38_row0_col85, #T_30a38_row0_col86, #T_30a38_row0_col87, #T_30a38_row0_col88, #T_30a38_row0_col89, #T_30a38_row0_col90, #T_30a38_row0_col91, #T_30a38_row0_col92, #T_30a38_row0_col93, #T_30a38_row0_col94, #T_30a38_row0_col95, #T_30a38_row0_col96, #T_30a38_row0_col97, #T_30a38_row0_col98, #T_30a38_row0_col99, #T_30a38_row0_col100, #T_30a38_row0_col101, #T_30a38_row0_col102, #T_30a38_row0_col103, #T_30a38_row0_col104, #T_30a38_row0_col105, #T_30a38_row0_col106, #T_30a38_row0_col107, #T_30a38_row0_col108, #T_30a38_row0_col109, #T_30a38_row0_col110, #T_30a38_row0_col111, #T_30a38_row0_col112, #T_30a38_row0_col113, #T_30a38_row0_col114, #T_30a38_row0_col115, #T_30a38_row0_col116, #T_30a38_row0_col117, #T_30a38_row0_col118, #T_30a38_row0_col119, #T_30a38_row0_col120, #T_30a38_row0_col121, #T_30a38_row0_col122, #T_30a38_row0_col123, #T_30a38_row0_col124, #T_30a38_row0_col125, #T_30a38_row0_col126, #T_30a38_row0_col127, #T_30a38_row0_col128, #T_30a38_row0_col129, #T_30a38_row0_col130, #T_30a38_row0_col131, #T_30a38_row1_col0, #T_30a38_row1_col1, #T_30a38_row1_col2, #T_30a38_row1_col3, #T_30a38_row1_col4, #T_30a38_row1_col5, #T_30a38_row1_col6, #T_30a38_row1_col7, #T_30a38_row1_col8, #T_30a38_row1_col9, #T_30a38_row1_col10, #T_30a38_row1_col11, #T_30a38_row1_col12, #T_30a38_row1_col13, #T_30a38_row1_col14, #T_30a38_row1_col15, #T_30a38_row1_col16, #T_30a38_row1_col17, #T_30a38_row1_col18, #T_30a38_row1_col19, #T_30a38_row1_col20, #T_30a38_row1_col21, #T_30a38_row1_col22, #T_30a38_row1_col23, #T_30a38_row1_col24, #T_30a38_row1_col25, #T_30a38_row1_col26, #T_30a38_row1_col27, #T_30a38_row1_col28, #T_30a38_row1_col29, #T_30a38_row1_col30, #T_30a38_row1_col31, #T_30a38_row1_col32, #T_30a38_row1_col33, #T_30a38_row1_col34, #T_30a38_row1_col35, #T_30a38_row1_col36, #T_30a38_row1_col37, #T_30a38_row1_col38, #T_30a38_row1_col39, #T_30a38_row1_col40, #T_30a38_row1_col41, #T_30a38_row1_col42, #T_30a38_row1_col43, #T_30a38_row1_col44, #T_30a38_row1_col45, #T_30a38_row1_col46, #T_30a38_row1_col47, #T_30a38_row1_col48, #T_30a38_row1_col49, #T_30a38_row1_col50, #T_30a38_row1_col51, #T_30a38_row1_col52, #T_30a38_row1_col53, #T_30a38_row1_col54, #T_30a38_row1_col62, #T_30a38_row1_col63, #T_30a38_row1_col64, #T_30a38_row1_col65, #T_30a38_row1_col66, #T_30a38_row1_col72, #T_30a38_row1_col73, #T_30a38_row1_col74 ...

# %% [markdown]
# **Посмотрим в 2D**

# %%
# Проведем визуализацию распределения тем
df_2d = topic_model.visualize_topics()  # Визуализируем темы
df_2d.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6d21e834-77d4-4d62-b73b-c43ca58fbdd7" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d21e834-77d4-4d62-b73b-c43ca58fbdd7")) {                    Plotly.newPlot(                        "6d21e834-77d4-4d62-b73b-c43ca58fbdd7",                        [{"customdata":[[0,"студийный | scars | пластинка | лейбл | сольный",52],[1,"playstation | геймер | eurogamer | fallout | killzone",37],[2,"украинец | боксерский | весовой | кличко | boxingscene",33],[3,"ходорковский | лжепредпринимательство | ходатайство | юриспруденция | уклонение",33],[4,"звездообразование | астрономический | астрофизик | астроном | галактика",28],[5,"сербский | югославский | серб | черногорский | балканский",24],[6,"котировка | понизиться | фьючерс | биржа | фондовый",24],[7,"космический | космодром | аккумуляторный | орбитальный | аэробаллистический",23],[8,"донецкий | ополченец | украиной | силовик | минский",22],[9,"генетический | генетик | геном | neanderthalensis | неандертальский",22],[10,"пенсионный | пенсия | соплатежей | экономически | недополучать",21],[11,"хроникаучастница | толоконникова | ходорковский | активист | оппозиционер",21],[12,"пожарный | противопожарный | новостипредставителить | потушить | сгореть",20],[13,"биатлонист | эстафетный | биатлонистка | эстафета | биатлон",20],[14,"капитанский | англичанин | гленторан | скоулзти | лондонец",20],[15,"ипотечный | кредитование | потребкредит | заемщик | ипотека",20],[16,"грузинский | гачечиладзе | оппозиционный | бурджанадзе | гецадзе",20],[17,"стрелять | застрелить | выстрелить | афроамериканец | плейный",18],[18,"кинематографический | кинотавр | film | кинофестиваль | кино",18],[19,"ковыкт | ковыктой | ковыкты | ковыктинский | акционер",18],[20,"сирийский | сириец | сирии | мистур | исламский",18],[21,"северокорейский | корейский | пхеньяном | корея | кореи",17],[22,"израильпроветь | израильтянин | израильсике | палестинец | палестинский",17],[23,"иракец | иракский | шиитский | багдадский | шиит",17],[24,"хоккейный | хоккеист | хоккей | шайба | канадец",16],[25,"судостроительный | кораблестроение | фрегат | водоизмещение | эсминец",16],[26,"демократичность | антироссийский | апелляционный | сбрить | демократ",16],[27,"joaillerie | ювелирно | jewellery | ювелирный | кутюрье",16],[28,"хоккеист | хокс | кэпиталс | шайба | овечкин",16],[29,"банковский | энтузиастбанк | депозитный | вестинтербанк | кредитный",15],[30,"гоночный | автогонкам | автогонки | трасса | гонщик",15],[31,"экономкласс | эконом | ценовой | ценовый | жилье",15],[32,"поляк | majewski | переименовать | польский | коммунистический",15],[33,"nvidia | видеокарта | ноутбук | дисплей | сенсорный",14],[34,"великобританией | диппредставительство | скрипалей | скрипаля | дипломатия",14],[35,"еврооблигация | евробонд | реструктуризировать | долг | заем",14],[36,"нижнесилезский | горноспасательный | горноспасатель | медный | рудный",14],[37,"лайнер | индонезийский | авиакатастрофа | еврокоптер | джаяпур",14],[38,"турецкий | турция | турок | йылдырым | hürriyet",13],[39,"иракец | иракский | ибрагим | постсаддамовский | malekzadeh",13],[40,"португалец | неаполитанец | мадридский | стоичков | туринец",13],[41,"южноосетинский | грузинский | грузиный | грузино | грузия",13],[42,"видеореклама | рекламный | блогохостинг | видеохостинг | микроблогерский",13],[43,"nokia | видеоконференц | медиаплеер | slashgear | смартфон",13],[44,"законтрактовать | дефицит | бездефицитный | нефтепродукт | нефтепродукты",13],[45,"наночастица | частица | электромагнитный | электроника | нейтронный",12],[46,"кинопрокатный | кинопрокат | кинопрокатчика | кассовый | анимацонный",12],[47,"газотранспортный | газпромом | словацкий | ставицкий | украину",12],[48,"fi ...

# %% [markdown]
# **4. Расчет метрик**

# %% [markdown]
# **Оценим результат по метрике Topic Diversity**

# %%
def topic_diversity(topic_words, top_n=10):
    all_words = [word for topic in topic_words for word in topic[:top_n]]
    unique_words = set(all_words)
    return len(unique_words) / (top_n * len(topic_words))

topics = topic_model.get_topics()
topic_words = [words for _, words in topics.items()]
td_score = topic_diversity(topic_words, top_n=10)
print(f"Topic Diversity: {td_score:.4f}")
# Out:
# Topic Diversity: 1.0000

# %% [markdown]
# Такая высокая оценка говорит о том, что у нас отлично получилось обеспечить разнообразие топиков

# %% [markdown]
# **Оценим результат по метрике UMass Coherence**

# %%
texts = [doc.split() for doc in df_sample['lemmatized']]

# Получаем топ-слова по темам (фильтруем пустые)
topics = topic_model.get_topics()
topic_words = [
    [word for word, _ in topic[:10]]
    for topic in topics.values()
    if len(topic) >= 10  # только темы с ≥10 словами
]
# Параметры
epsilon = 1  # сглаживание
top_n = 10   # кол-во слов в теме

# Подготовка частот
word_doc_freq = defaultdict(int)
word_pair_doc_freq = defaultdict(int)

for doc in texts:
    unique_words = set(doc)
    for word in unique_words:
        word_doc_freq[word] += 1
    for word1 in unique_words:
        for word2 in unique_words:
            if word1 != word2:
                word_pair_doc_freq[(word1, word2)] += 1

# Расчёт u_mass для каждой темы
topic_umass_scores = []

for topic in topic_words:
    score = 0.0
    pairs = 0
    for i in range(1, len(topic)):
        for j in range(i):
            wi = topic[i]
            wj = topic[j]
            D_wi_wj = word_pair_doc_freq.get((wi, wj), 0)
            D_wj = word_doc_freq.get(wj, 0)
            if D_wj > 0:
                score += math.log((D_wi_wj + epsilon) / D_wj)
                pairs += 1
    if pairs > 0:
        topic_umass_scores.append(score / pairs)

# Итоговый UMass
final_umass = sum(topic_umass_scores) / len(topic_umass_scores)
print(f"UMass Coherence: {final_umass:.4f}")
# Out:
# UMass Coherence: -1.6190

# %% [markdown]
# Отрицательное значение Umass может указывать на то, что слова внутри темы не всегда часто встречаются вместе в тех же документах. В некоторых случаях, если темы разрознены или слишком обобщены, они могут иметь отрицательное значение.
#
# - Меньшие значения говорят о том, что для данной темы нужно улучшить её фокусировку (например, уменьшить количество пересекающихся слов из разных областей).
# - Это может означать, что модель генерирует более разрозненные темы или что сам корпус не слишком однороден.

# %% [markdown]
# **5. Выводы**

# %% [markdown]
# **Чего удалось добиться:**
#
# - Модель выделила разнообразные темы, которые можно интерпретировать (например, политика, мода, игры и строительство)
#
# - Получены метки кластеров для документов, что позволяет анализировать распределение и выявлять основные темы
#
# **Идеи для дальнейших улучшений:**
#
# - Применить дополнительные методы очистки данных (например, удаление редких слов, спецсимволов)
#
# - Поэкспериментировать с параметрами HDBSCAN (например, увеличить минимальный размер кластера)
#
# - Попробовать другие модели тематического моделирования, такие как LDA или NMF, для сравнения результатов
